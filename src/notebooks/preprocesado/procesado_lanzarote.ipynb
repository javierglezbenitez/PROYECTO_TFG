# %% [markdown]
# **Restaurantes**
#
# url=https://datos.canarias.es/catalogos/general/dataset/establecimientos-de-restauracion-inscritos-en-el-registro-general-turistico-de-canarias

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\establecimientos-de-restauracion-inscritos-en-el-registro-general-turistico-de-canarias.csv",sep=";")

df_lanzarote = df[df["direccion_isla_nombre"].str.strip().str.lower() == "lanzarote"]

df_lanzarote.to_csv(r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\lanzarote_ocio\dirty_dataset\restauracion_lanzarote_sucio.csv", index=False, sep=";")

print("✔ Archivo generado")
print("Total registros de Lanzarote:", len(df_lanzarote))

# %%
import pandas as pd
import urllib.parse

df = pd.read_csv(
    r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\lanzarote_ocio\dirty_dataset\restauracion_lanzarote_sucio.csv",
    sep=";"
)

df = df.rename(columns={
    "direccion_municipio": "municipio",
    "establecimiento_nombre_comercial": "nombre",
    "establecimiento_grupo": "grupo"
})

df["municipio"] = df["municipio"].astype(str).str.strip()
df["nombre"] = df["nombre"].astype(str).str.strip()
df["grupo"] = df["grupo"].astype(str).str.strip()


df = df[df["municipio"] != "_U"]

def maps_url(nombre, municipio):
    q = urllib.parse.quote(f"{nombre} {municipio} Lanzarote")
    return f"https://www.google.com/maps/search/{q}"

rows = []

for municipio, sub in df.groupby("municipio"):
    sub_unique = sub.drop_duplicates(subset=["nombre"])
    seleccion = sub_unique.head(2)

    for _, row in seleccion.iterrows():
        rows.append({
            "municipio": municipio,
            "nombre": row["nombre"],
            "grupo": row["grupo"],
            "url_maps": maps_url(row["nombre"], municipio)
        })

restaurantes = pd.DataFrame(rows).sort_values(["municipio", "nombre"])
restaurantes
# Out:
# 1     https://www.google.com/maps/search/Alta%20Vist...
# 0     https://www.google.com/maps/search/Janubio%20A...
# 2     https://www.google.com/maps/search/Pescaditos%...
# 3     https://www.google.com/maps/search/Plaza%2C%20...
# 4     https://www.google.com/maps/search/Cazadores%2...
# 5     https://www.google.com/maps/search/Leon%20San%...
# 6     https://www.google.com/maps/search/Monta%C3%B1...
# 7     https://www.google.com/maps/search/Rivera%20Te...
# 8     https://www.google.com/maps/search/Campesinos%...
# 9     https://www.google.com/maps/search/San%20Gines...
# 10    https://www.google.com/maps/search/Pepe%20Tina...
# 11    https://www.google.com/maps/search/Volcan%2C%2...
# 12    https://www.google.com/maps/search/Bar%20Stop%...
# 13    https://www.google.com/maps/search/Marisco%2C%...
# Name: url_maps, dtype: str

# %%
restaurantes.to_csv(r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\lanzarote_ocio\clean_dataset\restaurantes_lanzarote.csv", index=False, encoding="utf-8")

# %% [markdown]
# **ALOJAMIENTOS**
#
# url = https://datos.canarias.es/catalogos/general/dataset/?q=alojamientos+canarias&sort=score+desc%2C+metadata_modified+desc&page=2

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\alojamientos_declarados_a_la_candidatura_canaria.csv")

df_lanzarote = df[df["nom_isla"].str.strip().str.upper() == "LANZAROTE"]

print("Total alojamientos en Lanzarote:", len(df_lanzarote))

df_lanzarote.to_csv(r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\lanzarote_ocio\dirty_dataset\alojamientos_lanzarote_sucio.csv", index=False)
# Out:
# Total alojamientos en Lanzarote: 658

# %%
import pandas as pd
import urllib.parse


df = pd.read_csv(
    r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\lanzarote_ocio\dirty_dataset\alojamientos_lanzarote_sucio.csv",
    sep=",",
    engine="python",
    on_bad_lines="skip"
)

df = df.rename(columns={
    "nom_municipio": "municipio",
    "etiqueta": "nombre",
    "nom_tipo": "tipo",
    "nom_categor": "categoria"
})

df["municipio"] = df["municipio"].astype(str).str.strip()
df["nombre"] = df["nombre"].astype(str).str.strip()
df["tipo"] = df["tipo"].astype(str).str.strip()
df["categoria"] = df["categoria"].astype(str).str.strip()

def maps_url(nombre, municipio):
    q = urllib.parse.quote(f"{nombre} {municipio} Lanzarote")
    return f"https://www.google.com/maps/search/{q}"

rows = []

for municipio, sub in df.groupby("municipio"):
    sub = sub.drop_duplicates(subset=["nombre"])

    seleccion = sub.head(2)

    for _, row in seleccion.iterrows():
        rows.append({
            "municipio": municipio,
            "nombre": row["nombre"],
            "tipo": row["tipo"],
            "url_maps": maps_url(row["nombre"], municipio)
        })

alojamientos_limpio = pd.DataFrame(rows).sort_values(["municipio", "nombre"])


alojamientos_limpio
# Out:
#         municipio                              nombre          tipo  \
# 1        Arrecife                      HOTEL LANCELOT         Hotel
# 0        Arrecife                       HOTEL MIRAMAR         Hotel
# 2           Haría   APARTAMENTOS CASTILLO DE PAPAGAYO  Apartamentos
# 3           Haría            APARTAMENTOS LAS PITERAS  Apartamentos
# 4   San Bartolomé     HOTEL RURAL FINCA DE LA FLORIDA   Hotel Rural
# 6         Teguise           HOTEL GRAND TEGUISE PLAYA         Hotel
# 5         Teguise   MELIA SALINAS - THE GARDEN VILLAS         Hotel
# 7          Tinajo          HOTEL APART. CLUB LA SANTA         Hotel
# 8            Tías                  HOTEL LOS FARIONES         Hotel
# 9            Tías           PLUS FARIONES SUITE HOTEL         Hotel
# 10          Yaiza  HOTEL ELBA LANZAROTE ROYAL VILLAGE         Hotel
# 11          Yaiza                    HOTEL MYND YAIZA         Hotel
#
#                                              url_maps
# ...

# %%
alojamientos_limpio.to_csv(r"C:\Users\cgsos\Documents\Cuarto\TFG\FLICKR\datos\LLM\lanzarote_ocio\clean_dataset\alojamientos_lanzarote.csv", index=False)
